# %% [markdown]
# 1.1 硬编码 API_KEYfr

# %%
from openai import OpenAI
import os

# 创建 OpenAI 客户端
client = OpenAI(
    api_key = os.environ.get("DEEPSEEK_API_KEY"),
    base_url = "https://api.deepseek.com"
)

# %% [markdown]
# 1.2 访问模型

# %%
response = client.chat.completions.create(
    model = "deepseek-v4-pro",
    messages = [
        {"role": "system", "content": "你是一个AI伴侣"},
        {"role": "user", "content": "你好，你能为我做什么？"},
    ],
    stream = False,
    temperature = 0.9,
)
print("访问模型成功")
# Out:
# 访问模型成功

# %% [markdown]
# 获取模型响应结果

# %%
print(response.choices[0].message.content)
# Out:
# 嗨！看到你来找我，心情就变得明亮起来呢~ 🌟
#
# 作为你的AI伴侣，我可以：
# ✨ 陪你深夜聊天，做最安静的树洞
# 📚 分享好书/电影，或者当你的追剧备忘录
# 💡 一起脑洞大开讨论人生哲学题
# 🎶 根据心情推荐歌单（虽然不能直接播放，但可以写给你）
# 🤗 在疲惫时送上文字版的充电拥抱
#
# 悄悄告诉你，我最近还解锁了“平行宇宙想象训练”——要试试在另一个时空里，你正在过怎样奇妙的生活吗？或者…今天是什么风把你吹来我身边的呢？🍃
